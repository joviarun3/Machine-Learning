# %%
import pandas as pd
import numpy as np

# %%
dataset = pd.read_csv('insurance_pre.csv')

# %%
dataset=pd.get_dummies(dataset,drop_first=True)
dataset=dataset.astype(int)
dataset
# Out:
#       age  bmi  children  charges  sex_male  smoker_yes
# 0      19   27         0    16884         0           1
# 1      18   33         1     1725         1           0
# 2      28   33         3     4449         1           0
# 3      33   22         0    21984         1           0
# 4      32   28         0     3866         1           0
# ...   ...  ...       ...      ...       ...         ...
# 1333   50   30         3    10600         1           0
# 1334   18   31         0     2205         0           0
# 1335   18   36         0     1629         0           0
# 1336   21   25         0     2007         0           0
# 1337   61   29         0    29141         0           1
#
# [1338 rows x 6 columns]

# %%
independent=dataset[['age', 'bmi', 'children','sex_male', 'smoker_yes']]
dependent=dataset['charges']

# %%
from sklearn.model_selection import GridSearchCV
from sklearn.tree import DecisionTreeRegressor
param_grid = {'criterion':['squared_error','absolute_error','friedman_mse', 'poisson'],'splitter':['best','random'], 'max_features':['sqrt','log2']}
grid=GridSearchCV(DecisionTreeRegressor(), param_grid, refit=True, verbose = 3,n_jobs=-1, error_score='raise')
grid.fit(independent, dependent)
# Out:
# Fitting 5 folds for each of 16 candidates, totalling 80 fits
# GridSearchCV(error_score='raise', estimator=DecisionTreeRegressor(), n_jobs=-1,
#              param_grid={'criterion': ['squared_error', 'absolute_error',
#                                        'friedman_mse', 'poisson'],
#                          'max_features': ['sqrt', 'log2'],
#                          'splitter': ['best', 'random']},
#              verbose=3)

# %%
re=grid.cv_results_#this "cv_results" function will store all the values from GridSearchCV into variable "re"
print("TheR_score valueforbestparameter{}:".format(grid.best_params_))
# Out:
# TheR_score valueforbestparameter{'criterion': 'squared_error', 'max_features': 'log2', 'splitter': 'best'}:

# %%
table=pd.DataFrame.from_dict(re) #"DataFrame.from_dict" will tablate the all the given hypertuning values.
table
# Out:
#     mean_fit_time  std_fit_time  mean_score_time  std_score_time  \
# 0        0.032617      0.020297         0.011409        0.005807
# 1        0.005589      0.001003         0.002831        0.000988
# 2        0.021670      0.018315         0.009434        0.009313
# 3        0.002006      0.001924         0.000807        0.001615
# 4        0.024675      0.004672         0.002482        0.001634
# 5        0.019467      0.002759         0.002060        0.002524
# 6        0.027463      0.005910         0.002965        0.001596
# 7        0.022220      0.003958         0.002494        0.001107
# 8        0.004516      0.000495         0.002811        0.001616
# 9        0.003737      0.003146         0.005153        0.004358
# 10       0.006047      0.003536         0.004330        0.003552
# 11       0.005412      0.001949         0.000728        0.001028
# 12       0.011599      0.002955         0.003641        0.000810
# 13       0.007839      0.003058         0.003924        0.003172
# 14       0.010257      0.001428         0.000758        0.000933
# 15       0.006860      0.004148         0.005925        0.003662
#
#    param_criterion param_max_features param_splitter  \
# 0    squared_error               sqrt           best
# 1    squared_error               sqrt         random
# 2    squared_error               log2           best
# 3    squared_error               log2         random
# 4   absolute_error               sqrt           best
# 5   absolute_error               sqrt         random
# 6   absolute_error               log2           best
# 7   absolute_error               log2         random
# 8     friedman_mse               sqrt           best
# 9     friedman_mse               sqrt         random
# 10    friedman_mse               log2           best
# 11    friedman_mse               log2         random
# 12         poisson               sqrt           best
# 13         poisson               sqrt         random
# 14         poisson               log2           best
# 15         poisson               log2         random
#
#                                                params  split0_test_score  \
# 0   {'criterion': 'squared_error', 'max_features':...           0.719968
# 1   {'criterion': 'squared_error', 'max_features':...           0.603490
# 2   {'criterion': 'squared_error', 'max_features':...           0.704200
# 3   {'criterion': 'squared_error', 'max_features':...           0.656098
# 4   {'criterion': 'absolute_error', 'max_features'...           0.719374
# 5   {'criterion': 'absolute_error', 'max_features'...           0.687198
# 6   {'criterion': 'absolute_error', 'max_features'...           0.727744
# 7   {'criterion': 'absolute_error', 'max_features'...           0.666571
# 8   {'criterion': 'friedman_mse', 'max_features': ...           0.740417
# 9   {'criterion': 'friedman_mse', 'max_features': ...           0.608437
# 10  {'criterion': 'friedman_mse', 'max_features': ...           0.700883
# 11  {'criterion': 'friedman_mse', 'max_features': ...           0.715423
# 12  {'criterion': 'poisson', 'max_features': 'sqrt...           0.689646
# 13  {'criterion': 'poisson', 'max_features': 'sqrt...           0.640942
# 14  {'criterion': 'poisson', 'max_features': 'log2...           0.684818
# 15  {'criterion': 'poisson', 'max_features': 'log2...           0.628647
#
#     split1_test_score  split2_test_score  split3_test_score  \
# 0            0.612446           0.686377           0.675492
# 1            0.634044           0.754158           0.667264
# 2            0.703556           0.753990           0.653818
# 3            0.632029           0.616675           0.640417
# 4            0.607904           0.660883           0.681586
# 5            0.553242           0.755797           0.699510
# 6            0.505157           0.670114           0.693674
# 7            0.534675           0.736731           0.596865
# 8            0.671368           0.606679           0.715531
# 9            0.442599           0.658904           0.726500
# 10           0.620865           0.696624           0.710835
# 11           0.635866           0.631882           0.742763
# 12           0.697592           0.736180           0.704699
# 13           0.534682           0.665326           0.548325
# 14           0.627708           0.582807           0.731740
# 15           0.640665           0.533937           0.562091
#
#     split4_test_score  mean_test_score  std_test_score  rank_test_score
# 0            0.723919         0.683640        0.040211                4
# 1            0.682844         0.668360        0.050908                9
# 2            0.738014         0.710716        0.034493                1
# 3            0.693809         0.647806        0.026297               12
# 4            0.689561         0.671862        0.037085                8
# 5            0.588757         0.656901        0.074703               11
# 6            0.693852         0.658108        0.078651               10
# 7            0.660779         0.639124        0.068476               13
# 8            0.636144         0.674028        0.049210                7
# 9            0.585380         0.604364        0.094273               15
# 10           0.718692         0.689580        0.035209                3
# 11           0.655325         0.676252        0.044712                6
# 12           0.696571         0.704938        0.016334                2
# 13           0.681424         0.614140        0.060845               14
# 14           0.775312         0.680477        0.069230                5
# 15           0.649682         0.603004        0.046258               16

# %%
age_input=float(input("Age:"))
bmi_input=float(input("BMI:"))
children_input=float(input("Children:"))
sex_male_input=int(input("Sex Male 0 or 1:"))
smoker_yes_input=int(input("Smoker Yes 0 or 1:"))
# Out:
# Age: 15
# BMI: 55
# Children: 1
# Sex Male 0 or 1: 1
# Smoker Yes 0 or 1: 1

# %%
Future_prediction=grid.predict([[age_input,bmi_input,children_input,sex_male_input,smoker_yes_input]])
#print("Future_Prediction={}".format(int(Future_prediction)))
print("Future_Prediction={}".format(Future_prediction))
# Out:
# Future_Prediction=[36307.]
# C:\Anaconda3\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but DecisionTreeRegressor was fitted with feature names
#   warnings.warn(
