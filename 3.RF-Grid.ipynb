# %%
import pandas as pd

# %%
dataset = pd.read_csv('insurance_pre.csv')

# %%
dataset=pd.get_dummies(dataset,drop_first=True)
dataset=dataset.astype(int)
dataset
# Out:
#       age  bmi  children  charges  sex_male  smoker_yes
# 0      19   27         0    16884         0           1
# 1      18   33         1     1725         1           0
# 2      28   33         3     4449         1           0
# 3      33   22         0    21984         1           0
# 4      32   28         0     3866         1           0
# ...   ...  ...       ...      ...       ...         ...
# 1333   50   30         3    10600         1           0
# 1334   18   31         0     2205         0           0
# 1335   18   36         0     1629         0           0
# 1336   21   25         0     2007         0           0
# 1337   61   29         0    29141         0           1
#
# [1338 rows x 6 columns]

# %%
independent=dataset[['age', 'bmi', 'children','sex_male', 'smoker_yes']]
dependent=dataset[['charges']]

# %%
from sklearn.model_selection import GridSearchCV
from sklearn.ensemble import RandomForestRegressor
#from sklearn.metrics import fbeta_score, make_scorer
#ftwo_scorer = make_scorer(fbeta_score, beta=2)
param_grid = {'criterion':['squared_error','friedman_mse', 'absolute_error', 'poisson'], 'max_features': [1,'sqrt','log2'], 'n_estimators':[10, 100]}
grid=GridSearchCV(RandomForestRegressor(), param_grid, refit=True, verbose = 3,n_jobs=-1, error_score='raise') #scoring=ftwo_scorer
grid.fit(independent, dependent)
# Out:
# Fitting 5 folds for each of 24 candidates, totalling 120 fits
# C:\Anaconda3\Lib\site-packages\sklearn\base.py:1473: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return fit_method(estimator, *args, **kwargs)
# GridSearchCV(error_score='raise', estimator=RandomForestRegressor(), n_jobs=-1,
#              param_grid={'criterion': ['squared_error', 'friedman_mse',
#                                        'absolute_error', 'poisson'],
#                          'max_features': [1, 'sqrt', 'log2'],
#                          'n_estimators': [10, 100]},
#              verbose=3)

# %%
re=grid.cv_results_#this "cv_results" function will store all the values from GridSearchCV into variable "re"
print("TheR_score valueforbestparameter{}:".format(grid.best_params_))
# Out:
# TheR_score valueforbestparameter{'criterion': 'absolute_error', 'max_features': 'sqrt', 'n_estimators': 100}:

# %%
table=pd.DataFrame.from_dict(re) #"DataFrame.from_dict" will tablate the all the given hypertuning values.
table
# Out:
#     mean_fit_time  std_fit_time  mean_score_time  std_score_time  \
# 0        0.350496      0.081003         0.056729        0.004633
# 1        3.220521      0.068694         0.182663        0.012439
# 2        0.445708      0.063648         0.058092        0.003403
# 3        3.283160      0.067477         0.164304        0.007950
# 4        0.383530      0.012684         0.057771        0.013929
# 5        3.108505      0.036816         0.156569        0.012966
# 6        0.424359      0.089787         0.050952        0.004356
# 7        3.019762      0.035733         0.162771        0.011528
# 8        0.366661      0.006123         0.056424        0.007784
# 9        3.146676      0.047038         0.164857        0.008966
# 10       0.442484      0.065462         0.055401        0.004659
# 11       3.201649      0.052103         0.172014        0.009540
# 12       0.926092      0.034183         0.045953        0.003992
# ...

# %%
age_input=float(input("Age:"))
bmi_input=float(input("BMI:"))
children_input=float(input("Children:"))
sex_male_input=int(input("Sex Male 0 or 1:"))
smoker_yes_input=int(input("Smoker Yes 0 or 1:"))
# Out:
# Age: 4
# BMI: 56
# Children: 5
# Sex Male 0 or 1: 1
# Smoker Yes 0 or 1: 1

# %%
Future_prediction=grid.predict([[age_input,bmi_input,children_input,sex_male_input,smoker_yes_input]])
print("Future_Prediction={}".format(Future_prediction))
# Out:
# Future_Prediction=[33830.045]
# C:\Anaconda3\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
